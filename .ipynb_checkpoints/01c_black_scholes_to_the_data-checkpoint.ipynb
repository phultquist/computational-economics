# %%
import numpy as np
import pandas as pd
import string
import random
import math
from scipy.stats import norm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Black-Scholes: Are Returns Normal?

# %%
# !pip install --upgrade pandas-datareader
from pandas_datareader import data
# Out:
# Requirement already up-to-date: pandas-datareader in /opt/anaconda3/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from pandas-datareader) (1.1.3)
# Requirement already satisfied, skipping upgrade: requests>=2.19.0 in /opt/anaconda3/lib/python3.8/site-packages (from pandas-datareader) (2.24.0)
# Requirement already satisfied, skipping upgrade: lxml in /opt/anaconda3/lib/python3.8/site-packages (from pandas-datareader) (4.6.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (1.19.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2020.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (1.25.11)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)

# %%
# import price data
price = data.DataReader("SPY", 
                       start='2000-1-01', 
                       end='2020-12-31', 
                       data_source='yahoo')
# import dividend data
divs = data.DataReader('SPY', 
                       'yahoo-dividends',
                       start='2000-1-01', 
                       end='2019-12-31')

print(price.head())
print('-----')
print(divs.head())
# Out:
#                  High         Low       Open     Close      Volume  Adj Close
# Date
# 2000-01-03  148.25000  143.875000  148.25000  145.4375   8164300.0  98.146072
# 2000-01-04  144.06250  139.640625  143.53125  139.7500   8089800.0  94.307983
# 2000-01-05  141.53125  137.250000  139.93750  140.0000  12177900.0  94.476685
# 2000-01-06  141.50000  137.750000  139.62500  137.7500   6227200.0  92.958336
# 2000-01-07  145.75000  140.062500  140.31250  145.7500   8066500.0  98.356987
# -----
#               action  value
# 2019-12-20  DIVIDEND  1.570
# 2019-09-20  DIVIDEND  1.384
# 2019-06-21  DIVIDEND  1.432
# 2019-03-15  DIVIDEND  1.233
# 2018-12-21  DIVIDEND  1.435

# %%
# plot price data over time
price['Close'].plot.line(title='Closing Price (USD)')
plt.savefig('spy_price_plot.png')

# %%
# merge dataframes
df = price.join(divs)
df = df.drop(columns=['Open', 'High', 'Low', 'Volume', 'Adj Close',
                      'action'], axis=1)

# fill in no dividend days with zeros
df['value'] = df['value'].fillna(0)
df.columns = ['close', 'div']


# calculate return  
df['previous close'] = df['close'].shift(periods=1, fill_value=np.nan)
df['return'] = (df['close'] - df['previous close'] + 
                df['div'])/df['previous close']

# drop the first row (cant calculate return from previous close)
df = df.dropna(subset=['return'])
df
# Out:
#                  close  div  previous close    return
# Date
# 2000-01-04  139.750000  0.0      145.437500 -0.039106
# 2000-01-05  140.000000  0.0      139.750000  0.001789
# 2000-01-06  137.750000  0.0      140.000000 -0.016071
# 2000-01-07  145.750000  0.0      137.750000  0.058076
# 2000-01-10  146.250000  0.0      145.750000  0.003431
# ...                ...  ...             ...       ...
# 2020-12-24  369.000000  0.0      367.570007  0.003890
# 2020-12-28  372.170013  0.0      369.000000  0.008591
# 2020-12-29  371.459991  0.0      372.170013 -0.001908
# 2020-12-30  371.989990  0.0      371.459991  0.001427
# 2020-12-31  373.880005  0.0      371.989990  0.005081
#
# [5283 rows x 4 columns]

# %%
# plot returns over time
df['return'].plot.line(title='Returns')
plt.savefig('spy_returns_plot.png')

# %%
# sort the data by returns
dfsorted = df.sort_values(by=['return'])
dfsorted
# Out:
#                  close  div  previous close    return
# Date
# 2020-03-16  239.850006  0.0      269.320007 -0.109424
# 2008-10-15   90.019997  0.0       99.849998 -0.098448
# 2020-03-12  248.110001  0.0      274.359985 -0.095677
# 2008-12-01   82.110001  0.0       90.089996 -0.088578
# 2008-09-29  111.379997  0.0      120.849998 -0.078362
# ...                ...  ...             ...       ...
# 2009-03-23   82.220001  0.0       76.709999  0.071829
# 2020-03-13  269.320007  0.0      248.110001  0.085486
# 2020-03-24  243.149994  0.0      222.949997  0.090603
# 2008-10-28   93.760002  0.0       83.949997  0.116855
# 2008-10-13  101.349998  0.0       88.500000  0.145198
#
# [5283 rows x 4 columns]

# %%
# calculate the cdf
print(dfsorted.count())
dfsorted['N'] = np.arange(len(dfsorted))
dfsorted['cdf'] = dfsorted['N'] /(5030+1)
dfsorted
# Out:
# close             5283
# div               5283
# previous close    5283
# return            5283
# dtype: int64
#                  close  div  previous close    return     N       cdf
# Date
# 2020-03-16  239.850006  0.0      269.320007 -0.109424     0  0.000000
# 2008-10-15   90.019997  0.0       99.849998 -0.098448     1  0.000199
# 2020-03-12  248.110001  0.0      274.359985 -0.095677     2  0.000398
# 2008-12-01   82.110001  0.0       90.089996 -0.088578     3  0.000596
# 2008-09-29  111.379997  0.0      120.849998 -0.078362     4  0.000795
# ...                ...  ...             ...       ...   ...       ...
# 2009-03-23   82.220001  0.0       76.709999  0.071829  5278  1.049096
# 2020-03-13  269.320007  0.0      248.110001  0.085486  5279  1.049294
# 2020-03-24  243.149994  0.0      222.949997  0.090603  5280  1.049493
# 2008-10-28   93.760002  0.0       83.949997  0.116855  5281  1.049692
# 2008-10-13  101.349998  0.0       88.500000  0.145198  5282  1.049891
#
# [5283 rows x 6 columns]

# %%
# plot the cdf scatter 
ax = dfsorted.plot.scatter(x='return', y='cdf', title='CDF of Returns')
plt.ylabel('CDF')
plt.xlabel('Return')
plt.savefig('spy_cdf_plot.png')

# %%
# plot the cdf scatter 
# using log scale
ax = dfsorted.plot.scatter(x='return', y='cdf', logy=True, ylim=(.0001,1.1), title='CDF of Returns')
plt.ylabel('CDF (log scale)')
plt.xlabel('Return')
plt.savefig('spy_cdf_log_plot.png')

# %%
# calculate the 1-cdf
dfsorted['1-cdf'] = 1-dfsorted['cdf']

# cdf is return is negative, and 1-cdf if return is positive
dfsorted.loc[df['return']>0, 'cdf, 1-cdf'] = dfsorted['1-cdf']
dfsorted.loc[df['return']<=0, 'cdf, 1-cdf'] = dfsorted['cdf']

dfsorted
# Out:
#                  close  div  previous close    return     N       cdf  \
# Date
# 2020-03-16  239.850006  0.0      269.320007 -0.109424     0  0.000000
# 2008-10-15   90.019997  0.0       99.849998 -0.098448     1  0.000199
# 2020-03-12  248.110001  0.0      274.359985 -0.095677     2  0.000398
# 2008-12-01   82.110001  0.0       90.089996 -0.088578     3  0.000596
# 2008-09-29  111.379997  0.0      120.849998 -0.078362     4  0.000795
# ...                ...  ...             ...       ...   ...       ...
# 2009-03-23   82.220001  0.0       76.709999  0.071829  5278  1.049096
# 2020-03-13  269.320007  0.0      248.110001  0.085486  5279  1.049294
# 2020-03-24  243.149994  0.0      222.949997  0.090603  5280  1.049493
# 2008-10-28   93.760002  0.0       83.949997  0.116855  5281  1.049692
# 2008-10-13  101.349998  0.0       88.500000  0.145198  5282  1.049891
#
#                1-cdf  cdf, 1-cdf
# Date
# 2020-03-16  1.000000    0.000000
# 2008-10-15  0.999801    0.000199
# 2020-03-12  0.999602    0.000398
# 2008-12-01  0.999404    0.000596
# 2008-09-29  0.999205    0.000795
# ...              ...         ...
# 2009-03-23 -0.049096   -0.049096
# 2020-03-13 -0.049294   -0.049294
# 2020-03-24 -0.049493   -0.049493
# 2008-10-28 -0.049692   -0.049692
# 2008-10-13 -0.049891   -0.049891
#
# [5283 rows x 8 columns]

# %%
# plot the cdf, 1-cdf scatter 
# using log scale
ax = dfsorted.plot.scatter(x='return', y='cdf, 1-cdf', logy=True, 
                      xlim=(-.17, .17), ylim=(.0001,1), title='CDF, 1-CDF')
plt.ylabel('CDF, 1-CDF (log scale)')
plt.xlabel('Return')
plt.savefig('spy_cdf_1minus_log_plot.png')

# %%
# calculate mean and std
print(dfsorted['return'].mean())
print(dfsorted['return'].std())
# Out:
# 0.000303831290834255
# 0.01194892004685354

# %%
# calculate the cdf, 1-cdf, and both
dfsorted['norm_cdf'] = norm.cdf(dfsorted['return'], loc=0.0003, scale =.0119)
dfsorted['1-norm_cdf'] = 1-dfsorted['norm_cdf']

dfsorted.loc[df['return']>0, 'norm_cdf, 1-norm_cdf'] = dfsorted['1-norm_cdf']
dfsorted.loc[df['return']<0, 'norm_cdf, 1-norm_cdf'] = dfsorted['norm_cdf']

dfsorted[['norm_cdf', '1-norm_cdf', 'norm_cdf, 1-norm_cdf', 'return']]
# Out:
#                 norm_cdf    1-norm_cdf  norm_cdf, 1-norm_cdf    return
# Date
# 2008-10-15  5.288354e-17  1.000000e+00          5.288354e-17 -0.098448
# 2008-12-01  4.048217e-14  1.000000e+00          4.048217e-14 -0.088578
# 2008-09-29  1.918748e-11  1.000000e+00          1.918748e-11 -0.078362
# 2008-11-20  1.884678e-10  1.000000e+00          1.884678e-10 -0.074233
# 2008-10-09  1.884361e-09  1.000000e+00          1.884361e-09 -0.069839
# ...                  ...           ...                   ...       ...
# 2008-11-13  9.999999e-01  9.269250e-08          9.269250e-08  0.062340
# 2008-11-24  1.000000e+00  3.364655e-09          3.364655e-09  0.069291
# 2009-03-23  1.000000e+00  9.228229e-10          9.228229e-10  0.071829
# 2008-10-28  1.000000e+00  0.000000e+00          0.000000e+00  0.116855
# 2008-10-13  1.000000e+00  0.000000e+00          0.000000e+00  0.145198
#
# [5030 rows x 4 columns]

# %%
ax = dfsorted.plot.scatter(x='return', y=['cdf, 1-cdf'], logy=True, 
                      xlim=(-.17, .17), ylim=(.0001,1))

dfsorted.plot.line(x='return', y=['norm_cdf, 1-norm_cdf'], logy=True, 
                      xlim=(-.17, .17), ylim=(.0001,1), ax=ax)

ax.legend(['Normal CDF, 1-CDF', 'Empirical CDF, 1-CDF'])
plt.ylabel('CDF, 1-CDF')
plt.xlabel('Return')
plt.savefig('spy_cdfs_and_normal_plot.png')

# %% [markdown]
# The center of the return distribution is roughly normally distributed. However, the tails are not. The normal distribution underpredicts the liklihood of days with very high or very low returns.
